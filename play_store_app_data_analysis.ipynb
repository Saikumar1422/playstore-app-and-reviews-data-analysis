# %% [markdown]
# <a href="https://colab.research.google.com/github/Saikumar1422/playstore-app-and-reviews-data-analysis/blob/main/play_store_app_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROJECT NAME**
# # Playstore data analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1. INTRODUCTION**
# # Google Play is a website and app that gives users access to download apps, books,game, movies, music, and other content from Google.
# #Android is the dominant mobile operating system today with about 85% of all mobile devices running Google’s OS.
# #The Google Play Store is the largest and most popular Android app store.The main purpose of the project was to gather and analyze perfectinformation on apps in the Google Play Store in order to provide insights on app features and the current state of the Android app market and also to predict the future concerns of app.

# %% [markdown]
# # **GITHUB LINK**

# %% [markdown]
# # **PROJECT SUMMARY**
# questions

# %% [markdown]
# ## 1. What are the top categories on the Play Store?
# ##2. Which category has the large number of installations?text?
# ## 3: Way that the app rating effect the application?
# ##4 Relationship between app category and app price Section?
# ## 5. distribution of Ratings and price over the dataframes?
# ## 6. What is percentage of Free and paid app?
# ## 7. comparing the segment factors?
# ## 8: The size of every app should shown in histogram representation?
# # 9.Comparing content rating and app rating with the type
# # 10 visualizing the pairplot for better understaning
# #11 indicating and compating installs and type of app with reg plot
# # 12 Comparing the rating with category

# %% [markdown]
# ## **understanding the data**

# %% [markdown]
# **Data Preprocessing** :
#
# 1. Getting the dataset
# 2. Importing libraries
# 3. Importing datasets
# 4  HANDLING NULL VALUES
# 5. Encoding Categorical Data
# 6. Data Cleaning and Feature Engineering

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#loading dataset
df=pd.read_csv("/content/drive/MyDrive/Play Store Data (1).csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2=pd.read_csv("/content/drive/MyDrive/User Reviews.csv")
df2
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# # DATA PREPROCISSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df2.info
# Out:
# <bound method DataFrame.info of                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# # HANDLING NULL VALUES

# %%
def imputenan(df,variable,median):
  # df[variable+"_median"]=df[variable].fillna(median)
  df[variable+'_random']=df[variable]
  random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
  random_sample.index=df[df[variable].isnull()].index
  df.loc[df[variable].isnull(),variable+'_random']=random_sample

# %%
median=df['Rating'].median()
median
# Out:
# 4.3

# %%
imputenan(df,'Rating',median)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # LETS CHECK THE ACCURACY OF RATING AFTER FILLING IT WITH NULL RANDOM VALUES

# %%
fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111)
sns.kdeplot(df['Rating'],color='b')
sns.kdeplot(df['Rating_random'],color='red')
labels=ax.get_legend_handles_labels()

# %% [markdown]
# Got the approximate rating values with the same distribution

# %%
df.drop(['Rating'],axis=1,inplace=True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Type'].fillna(df['Type'].mode()[0], inplace=True)
df['Current Ver'].fillna(df['Current Ver'].mode()[0], inplace=True)
df['Android Ver'].fillna(df['Android Ver'].mode()[0], inplace=True)
df['Content Rating'].fillna(df['Content Rating'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# Rating_random     0
# dtype: int64

# %%
df.rename(columns={'Rating_random':'Rating'},inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df['Rating'] > 5]
# Out:
#                                            App Category Reviews    Size  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    3.0M  1,000+
#
#       Installs Type     Price Content Rating             Genres Last Updated  \
# 10472     Free    0  Everyone       Everyone  February 11, 2018       1.0.19
#
#       Current Ver Android Ver  Rating
# 10472  4.0 and up  4.1 and up    19.0

# %%
df.drop([10472],inplace=True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # check user reviews

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df2.shape
# Out:
# (64295, 5)

# %%
df2.dropna()
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
df['Reviews'] = df['Reviews'].astype(int)
df['Reviews'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# converting all the reviews into a integer format gets easier ta handle

# %% [markdown]
# ## Removing '$' from Price colummn and converting it to float type

# %%
df['Price'] = df['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
df['Price'] = df['Price'].apply(lambda x: float(x))

# %% [markdown]
# # Removing '+' and ',' from Installs colummn and converting it to float type:

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %% [markdown]
# #  EXPLORATORY DATA ANALYSIS, DATA VISUALISATION,STORY TELLING,GRAPHS AND CHARTS

# %% [markdown]
# 1.First we can check the correlations based on the different columns in the data frame.
#
# 2.Also by using the correlations we can represent the heat map among the columns displayed

# %%
df.corr()
# Out:
#            Reviews  Installs     Price    Rating
# Reviews   1.000000  0.643122 -0.009667  0.063537
# Installs  0.643122  1.000000 -0.011689  0.048078
# Price    -0.009667 -0.011689  1.000000 -0.016928
# Rating    0.063537  0.048078 -0.016928  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Now lets check the pairplot for the play syore data set

# %%
sns.pairplot(df)

# %% [markdown]
# # **1. Let us check the top categories like large number of apps**

# %%
category_counts=df['Category'].value_counts().reset_index()
category_counts
# Out:
#                   index  Category
# 0                FAMILY      1972
# 1                  GAME      1144
# 2                 TOOLS       843
# 3               MEDICAL       463
# 4              BUSINESS       460
# 5          PRODUCTIVITY       424
# 6       PERSONALIZATION       392
# 7         COMMUNICATION       387
# 8                SPORTS       384
# 9             LIFESTYLE       382
# 10              FINANCE       366
# 11   HEALTH_AND_FITNESS       341
# 12          PHOTOGRAPHY       335
# 13               SOCIAL       295
# 14   NEWS_AND_MAGAZINES       283
# 15             SHOPPING       260
# 16     TRAVEL_AND_LOCAL       258
# 17               DATING       234
# 18  BOOKS_AND_REFERENCE       231
# 19        VIDEO_PLAYERS       175
# 20            EDUCATION       156
# 21        ENTERTAINMENT       149
# 22  MAPS_AND_NAVIGATION       137
# 23       FOOD_AND_DRINK       127
# 24       HOUSE_AND_HOME        88
# 25    AUTO_AND_VEHICLES        85
# ...

# %%
# %matplotlib inline

# %%
fig=plt.figure(figsize=(10,8))
sns.barplot(y= "index", x = "Category",data = category_counts)
plt.xlabel("counts")
plt.ylabel("category")
plt.title("Top catogories like more number of apps")
plt.show()

# %% [markdown]
# Concluding the above plot we can express that the **FAMILY** has maintained the top category among all apps
#
# **Game** amnd **Tools** maintain at second and third place of all categories
#
# **Beauty** and **Events** are installs are less compared to others

# %% [markdown]
# # 2. **Now look what are the top Genres in the playstore**

# %%
genres_apps = df['Genres'].value_counts().reset_index().head(10)
genres_apps
# Out:
#              index  Genres
# 0            Tools     842
# 1    Entertainment     623
# 2        Education     549
# 3          Medical     463
# 4         Business     460
# 5     Productivity     424
# 6           Sports     398
# 7  Personalization     392
# 8    Communication     387
# 9        Lifestyle     381

# %%
sns.set_context('talk')
plt.figure(figsize=(10,8))
ax = sns.barplot(y= "index", x = "Genres", data = genres_apps)# palette=("winter_r"))
plt.xlabel('Counts')
plt.ylabel('Genres')
plt.title('Top 10 Genres apps in Playstore' )
plt.show()

# %% [markdown]
# Here most of the apps are tool genres
#
# sports, Personalization, Communication, Lifestyle are ikely to be same

# %% [markdown]
# # 3. Lets check the Rating that occurs most among all ratings

# %%
plt.figure(figsize=(15,5))
plt.xlabel("Ratings")
plt.ylabel("Frequency")
graph = sns.kdeplot(df.Rating, color="r", cut = 0, fill = True , linewidth = 2 , alpha = 0.3)
plt.title('Most Common Rating',size = 20);

# %% [markdown]
# By plotting the rating that the rating of 4.3 causes mostly when compared to others

# %% [markdown]
# ### 4. **Most Common Anroid Version for Majority of the Apps**

# %%
df['Android Ver'].mode().reset_index()
# Out:
#    index Android Ver
# 0      0  4.1 and up

# %% [markdown]
# So the android version with '4.1 and up'has the majority of apps

# %% [markdown]
# #**5. Percentage of free and paid apps**

# %%
plt.pie(df['Type'].value_counts(), labels = df['Type'].unique(),autopct='%1.1f%%',)
plt.show()

# %% [markdown]
# By choosing the chart many od the apps in th playu stoire are free of cost rather than paid

# %% [markdown]
# # **6. Relationship between app category and app price Section**

# %%
graph, plot = plt.subplots()
graph.set_size_inches(16,10)
best_app= df[df.Category.isin(['GAME', 'FAMILY', 'PHOTOGRAPHY','MEDICAL', 'TOOLS', 'FINANCE','LIFESTYLE','BUSINESS'])]
plot = sns.stripplot(x = best_app['Price'], y = best_app['Category'], jitter=True, linewidth=1)
plot.set_title('App pricing trend across categories')
plot.set_xticklabels(plot.get_xticklabels(),rotation=90, horizontalalignment='right');
# Out:
# <ipython-input-40-d51aa5b18d9e>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_xticklabels(plot.get_xticklabels(),rotation=90, horizontalalignment='right');

# %% [markdown]
# Many factors to be consider when selecting the right pricing strategy for your mobile app. It is important to re-evaluate the app price before entering the market.Is it worth the pice or not?.
#
# Here we can see that Different categories apps demand different price ranges. Some apps that are simple and easy are free, where as apps in category family lifestyle finance and medical are high in price.
#
# all Game apps are comparetively low in price, may be thats the reason game apps have more number of downloads, as we have seen earlier.

# %% [markdown]
# ### **7 TOP 10 Apps** with the most number of **Positive Reviews** *italicized text*

# %%
positive_reviewed_apps = df2[df2['Sentiment'] == 'Positive']

top_positive = positive_reviewed_apps.groupby(['App'])['Sentiment'].count().reset_index().sort_values(by = 'Sentiment' , ascending = False).head(10)
top_positive
# Out:
#                                 App  Sentiment
# 805                      Helix Jump        209
# 502  Duolingo: Learn Languages Free        200
# 324        Calorie Counter - Macros        174
# 325  Calorie Counter - MyFitnessPal        169
# 256                      Bowmasters        169
# 0             10 Best Foods for You        162
# 744                   Google Photos        143
# 24     8fit Workouts & Meal Planner        137
# 708                Garena Free Fire        136
# 426             DRAGON BALL LEGENDS        127

# %%
sns.set_context('paper')
plt.figure(figsize=(15,6))
ax = sns.barplot(y= "App", x = "Sentiment", data = top_positive, palette=("PuRd_r"))
plt.xlabel('Positive Sentiment')
plt.ylabel('Apps')
plt.title('Top 20 Most Positive Reviewed Apps' , fontsize = 15)
plt.show()

# %% [markdown]
# **Duolingo: Learn Languages Free**	 is the **Most Positive Reviewed** app in playstore followed by **Helix Jump**,	**Bowmasters** and others

# %% [markdown]
# ### **8 .TOP 20 Apps** with the most number of **Negative Reviews**

# %%
ositive_reviewed_apps = df2[df2['Sentiment'] == 'Negative']

top_negative = positive_reviewed_apps.groupby(['App'])['Sentiment'].count().reset_index().sort_values(by = 'Sentiment' , ascending = False).head(20)
top_negative
# Out:
#                                                    App  Sentiment
# 805                                         Helix Jump        209
# 502                     Duolingo: Learn Languages Free        200
# 324                           Calorie Counter - Macros        174
# 325                     Calorie Counter - MyFitnessPal        169
# 256                                         Bowmasters        169
# 0                                10 Best Foods for You        162
# 744                                      Google Photos        143
# 24                        8fit Workouts & Meal Planner        137
# 708                                   Garena Free Fire        136
# 426                                DRAGON BALL LEGENDS        127
# 114                                Angry Birds Classic        124
# 293  CBS Sports App - Scores, News, Stats & Watch Live        123
# 375                            ColorNote Notepad Notes        121
# ...

# %%
sns.set_context('paper')
plt.figure(figsize=(15,6))
ax = sns.barplot(y= "App", x = "Sentiment", data = top_negative, palette=("Purples_r"))
plt.xlabel('Negative Sentiment')
plt.ylabel('Apps')
plt.title('Top 20 Most Negative Reviewed Apps' , fontsize = 15)
plt.show()

# %% [markdown]
# **Candy Crush Saga**	is the most negatively reviewed app on playstore followed by **8 Ball Pool**, **Angry Birds Classic**	and others...

# %% [markdown]
# # **9.Comparing content rating and app rating with the type**

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Content Rating',y='Rating',hue='Type')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Rating'>

# %% [markdown]
# here by the graph we have seen that CONTENT RATING WITH 'EVERYONE','TEEN','EVERYONE 10+'AND'MATURE 17+' has the same overall same rating with free and paid
#
#  As we compared with the other 'adult only 18+' and 'unrated' has no paid apps

# %% [markdown]
# # **10 visualizing the pairplot for better understaning**

# %%
sns.pairplot(df2,hue='Sentiment',kind='kde')

# %% [markdown]
# # **11 indicating and compating installs and type of app with reg plot**

# %%
plt.figure(figsize=(20,8))
sns.relplot(data=df,x='Type',y='Installs')#,hue='Type')

# %% [markdown]
# as the plotting seen that almost the free and paid installs are as same as other
#
# but a quiote differernce in some of the installs min 1000000000+ and 5000000000+

# %% [markdown]
# # **12 Comparing the rating with category**

# %%
f=sns.lineplot(data =df,x='Rating',y='Category')
f.set_xlim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# In the graph the rating is almost the same path game s and familyhas the 5 star rating whe  comparedto other categories
#
# and other category can make the app eithi low rating

# %% [markdown]
# #CONCLUTION

# %% [markdown]
#  1A **Positive Correlation** was seen between **Reviews** and **Installs**...which is kind of obvious, more the reviews more will be the people Installing those apps.\
#  Also a **Negative Correlation** was seen among **Ratings**, **Reviews**, & **Installs** with the Price.\
#   People are not satisfied with the services of paid apps, working on the    Reviews then offering somewhat discounts over those apps can be a great fix.
#
# \2 **TOOLS**, **ENTERTAINMENT**, **EDUCATION** are some of the **TOP Genres** in Playstore.
#
# 3 Most of the apps i.e **80.4%** are for **Everyone** i.e they do not have any age limitations, which indeed is a great move to attract people of every age groups.
#
#
# \
# 4 The **Average Size** of Apps on Playstore is around **20MB** which results in people downloading those apps without worrying about any storage issues, which may sometime be useful to bring in more Installs.
#
# \
# 5 About **70%** of the apps in Playstore are quite successful as they holds a Rating of **4.3** to **4.6/7** out of 5.
#
# \
# 6 The **Most Compatible Android Version** is **4.1 and above** as Most of the Apps from Playstore supports this Version.
#
# \
# 7 Around **93%** of the Apps on Playstore are **Free** and only **7%** are **Paid**, reason being the Negative Correlation among **Ratings**, **Reviews**, & **Installs** with the **Price** as we have analyzed earlier. The Success Rate for Paid Apps is less but never negligible.
#
# \
# 8 Also from the **Year Updation plot** we can see that the number of apps being updated is increasing with years, from 2017 to 2018 it has increased drastically  clearly indicating the interaction of these apps with the peopl
